# %% [markdown]
# # install dependencies

# %%
from utils import *

# %% [markdown]
# # Read/Generate instance

# %%
file_path = 'instances/instance0.txt'
vrp_instance = VRPDInstance.from_file(file_path)
print(vrp_instance)
# Out:
# ------------------------------------------------------------------------
# Instance file = instances/instance0.txt
# ------------------------------------------------------------------------
# number of vehicules (and drones)=2
# vehicle_capacities=[100, 150]
# drone_capacities=[50, 50],
# depot=(30, 30),
# Clients:
#   Client 1: Demand = 10, Location = (10, 20)
#   Client 2: Demand = 15, Location = (15, 30)
#   Client 3: Demand = 20, Location = (20, 30)
#   Client 4: Demand = 25, Location = (10, 5)
#   Client 5: Demand = 30, Location = (20, 15)
# ------------------------------------------------------------------------

# %%
solution = [(1,1,'T'), (2,1,'D'), (3,1,'T'), (4,2,'T'), (5,2,'T')]

printSolution(solution)
# Out:
# Client 1 est servi par le véhicule 1 avec un Camion.
# Client 2 est servi par le véhicule 1 avec un Drone.
# Client 3 est servi par le véhicule 1 avec un Camion.
# Client 4 est servi par le véhicule 2 avec un Camion.
# Client 5 est servi par le véhicule 2 avec un Camion.

# %%
from utils import drawGraph

drawGraph(vrp_instance, solution, saveSolution=True, showGraph=True)
# Out:
# Image has been saved succesfully -- Image fileName: VRPDSolution.png
